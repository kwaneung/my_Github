# %% [markdown]
# # P4DA Chapter5 Pandas Basics : 실습문제

# %% [markdown]
# ## 1. 다음 명령으로 타이타닉호 승객 데이터를 데이터프레임으로 읽어온다. 이 명령을 실행하려면 seaborn 패키지가 설치되어 있어야 한다.

# %% [markdown]
# import seaborn as sns
#
# titanic = sns.load_dataset("titanic")  # returns DataFrame

# %% [markdown]
# ### 타이타닉호 승객 데이터의 데이터 값을 구하라.

# %%
from pandas import DataFrame, Series
import seaborn as sns
titanic = sns.load_dataset("titanic")  
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic.to_csv('ch06/titanic.csv', index=False)

# %% [markdown]
# ## 2. 타이타닉호 승객들을 다음 각각의 기준으로 값을 구하라.
#     o 기준: 성별(sex) 인원수, 나이별(age) 인원수, 선실별(class) 인원수, 사망/생존(alive) 인원수를 구하라.

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
titanic['class'].value_counts()
# print('선실별 인원수'); print(titanic['age'].value_counts())
# print('사망/생존 인원수'); print(titanic['alive'].value_counts())
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# ## 3. 타이타닉 데이터를 이용하여 다음을 수행하라.
# ### 1) 다음과 같은 DataFrame을 만들라.
# - columns : age, embark_town
# - rows : sex, class

# %%
t1 = titanic[['sex','age','embark_town', 'class']].set_index(['sex','class'])
t1
# Out:
#                 age  embark_town
# sex    class
# male   Third   22.0  Southampton
# female First   38.0    Cherbourg
#        Third   26.0  Southampton
#        First   35.0  Southampton
# male   Third   35.0  Southampton
#        Third    NaN   Queenstown
#        First   54.0  Southampton
#        Third    2.0  Southampton
# female Third   27.0  Southampton
#        Second  14.0    Cherbourg
#        Third    4.0  Southampton
#        First   58.0  Southampton
# male   Third   20.0  Southampton
#        Third   39.0  Southampton
# female Third   14.0  Southampton
#        Second  55.0  Southampton
# male   Third    2.0   Queenstown
#        Second   NaN  Southampton
# female Third   31.0  Southampton
#        Third    NaN    Cherbourg
# male   Second  35.0  Southampton
#        Second  34.0  Southampton
# female Third   15.0   Queenstown
# male   First   28.0  Southampton
# female Third    8.0  Southampton
#        Third   38.0  Southampton
# male   Third    NaN    Cherbourg
# ...

# %% [markdown]
# ### 2) 성별, class로 정렬하라.

# %%
t2 = titanic[['sex','age','embark_town', 'class']].set_index(['sex','class'])
t3 = t2.sort_index(0,1)
print(t3)
# Out:
#                age  embark_town
# sex    class
# female First  38.0    Cherbourg
#        First  35.0  Southampton
#        First  58.0  Southampton
#        First   NaN    Cherbourg
#        First  49.0    Cherbourg
#        First  38.0          NaN
#        First  23.0  Southampton
#        First  19.0  Southampton
#        First  22.0  Southampton
#        First   NaN  Southampton
#        First  50.0    Cherbourg
#        First  44.0    Cherbourg
#        First  58.0    Cherbourg
#        First  31.0    Cherbourg
#        First  32.0    Cherbourg
#        First  35.0  Southampton
#        First   NaN    Cherbourg
#        First  30.0  Southampton
#        First  35.0    Cherbourg
#        First  58.0  Southampton
#        First  35.0  Southampton
#        First  63.0  Southampton
#        First  26.0  Southampton
#        First  19.0    Cherbourg
#        First   2.0  Southampton
#        First  50.0    Cherbourg
#        First   NaN    Cherbourg
# ...

# %%
### 3) 성별, class로 정렬하라.
